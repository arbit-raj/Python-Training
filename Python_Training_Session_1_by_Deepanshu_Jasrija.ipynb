# %% [markdown]
# <a href="https://colab.research.google.com/github/arbit-raj/Python-Training/blob/main/Python_Training_Session_1_by_Deepanshu_Jasrija.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filecontent = open("/content/demofile.txt", "r")

# %%
print(filecontent.read())
# Out:
# hello world

# %%
filecontent = open("/content/trialcsv.csv", "r")
print(filecontent.read())
# Out:
# a,b,c,d
# e,f,g,h

# %%
# importing csv module
import csv

# csv file name
filename = "trialcsv.csv"

# initializing the titles and rows list
fields = []
rows = []

# reading csv file
with open(filename, 'r') as csvfile:
	# creating a csv reader object
	csvreader = csv.reader(csvfile)
	
	# extracting field names through first row
	fields = next(csvreader)

	# extracting each data row one by one
	for row in csvreader:
		rows.append(row)

	# get total number of rows
	print("Total no. of rows: %d"%(csvreader.line_num))

# printing the field names
print('Field names are:' + ', '.join(field for field in fields))

# printing first 5 rows
print('\nFirst 5 rows are:\n')
for row in rows[:5]:
	# parsing each column of a row
	for col in row:
		print("%10s"%col),
	print('\n')
# Out:
# Total no. of rows: 4
# Field names are:a, b, c, d
#
# First 5 rows are:
#
#          e
#          f
#          g
#          h
#
#
#          i
#          j
#          k
#          l
#
#
#          m
#          n
#          o
#          p

# %%
# Python program to read 
# image using matplotlib
  
# importing matplotlib modules
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
  
# Read Images
img = mpimg.imread('Bouches du Rhone France.jpg')
  
# Output Images
plt.imshow(img)

# %%
# Python program to read
# image using PIL module
  
# importing PIL
from PIL import Image
  
# Read image
img = Image.open('Bouches du Rhone France.jpg')
  
# Output Images
img.show()
  
# prints format of image
print(img.format)
  
# prints mode of image
print(img.mode)
# Out:
# JPEG
# RGB

# %%
import numpy as np

records= np.array(89)
print(records)
# Out:
# 89

# %%
import numpy as np

records= np.array([89, 48, 27, 57])
print(records)
# Out:
# [89 48 27 57]

# %%
import numpy as np

records= np.array([[89, 48, 27, 57], [1, 4, 7, 10], [23, 36, 78, 90]])
print(records)
# Out:
# [[89 48 27 57]
#  [ 1  4  7 10]
#  [23 36 78 90]]

# %%
import numpy as np

records= np.array([[[1, 4, 7, 10], 48, 27, 57], [1, 4, 7, 10], [23, 36, 78, 90]])
print(records)
# Out:
# [[list([1, 4, 7, 10]) 48 27 57]
#  [1 4 7 10]
#  [23 36 78 90]]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import numpy as np

records= np.array([[[[1, 4, 7, 10], 48, 27, 57], [1, 4, 7, 10], [23, 36, 78, 90]]])
print(records)
print(records.ndim)
# Out:
# [[[list([1, 4, 7, 10]) 48 27 57]
#   [1 4 7 10]
#   [23 36 78 90]]]
# 3
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import numpy as np

records= np.array([[[[1, 4, 7, 10], 48, 27, 57], [1, 4, 7, 10], [23, 36, 78, 90]], [[[1, 4, 7, 10], 48, 27, 57], [1, 4, 7, 10], [23, 36, 78, 90]], [[[1, 4, 7, 10], 48, 27, 57], [1, 4, 7, 10], [23, 36, 78, 90]]])
print(records)
print(records.ndim)
print(records.shape)
# Out:
# [[[list([1, 4, 7, 10]) 48 27 57]
#   [1 4 7 10]
#   [23 36 78 90]]
#
#  [[list([1, 4, 7, 10]) 48 27 57]
#   [1 4 7 10]
#   [23 36 78 90]]
#
#  [[list([1, 4, 7, 10]) 48 27 57]
#   [1 4 7 10]
#   [23 36 78 90]]]
# 3
# (3, 3, 4)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
records= np.array([89, 48, 27, 57])
splrec= np.array_split(records, 2)
print(splrec)
# Out:
# [array([89, 48]), array([27, 57])]

# %%
records= np.array([89, 48, 27, 57])
splrec= np.array_split(records, 6)
print(splrec)
# Out:
# [array([89]), array([48]), array([27]), array([57]), array([], dtype=int64), array([], dtype=int64)]

# %%
records= np.array(["a", "b", "f", "h"])
splrec= np.array_split(records, 2)
print(splrec)
# Out:
# [array(['a', 'b'], dtype='<U1'), array(['f', 'h'], dtype='<U1')]

# %%
records= np.array([89, 48, 27, 57])
filter= []

for elemnt in records:
  if elemnt > 30:
    filter.append(True)
  else: 
    filter.append(False)

output = records[filter]

print(filter)
print(output)
# Out:
# [True, True, False, True]
# [89 48 57]

# %%
from google.colab import drive
drive.mount('/content/drive')
