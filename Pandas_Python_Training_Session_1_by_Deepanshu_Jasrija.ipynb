# %% [markdown]
# <a href="https://colab.research.google.com/github/arbit-raj/Python-Training/blob/main/Pandas_Python_Training_Session_1_by_Deepanshu_Jasrija.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

inp = pd.Series([1,57,36,7,np.nan,9])

inp
# Out:
# 0     1.0
# 1    57.0
# 2    36.0
# 3     7.0
# 4     NaN
# 5     9.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

df
# Out:
#                    A         B         C         D
# 2013-01-01  0.969637 -0.643217 -1.267306 -1.107879
# 2013-01-02 -1.824052  0.809720  0.195802 -0.164996
# 2013-01-03  0.142713 -1.332160 -0.783452 -0.477187
# 2013-01-04 -1.609044  0.762662  0.929138 -2.102355
# 2013-01-05  0.196282  1.178901 -0.421550 -1.737170
# 2013-01-06  0.395285 -0.110611 -0.098616  0.520833

# %%
df2 = pd.DataFrame(
     {
         "A": 1.0,
         "B": pd.Timestamp("20130102"),
         "C": pd.Series(1, index=list(range(4)), dtype="float32"),
         "D": np.array([3] * 4, dtype="int32"),
         "E": pd.Categorical(["test", "train", "test", "train"]),
         "F": "foo",
     }
 )

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.head()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.head(2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.tail(2)
# Out:
#      A          B    C  D      E    F
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.describe()
# Out:
#          A    C    D
# count  4.0  4.0  4.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2[1:3]
# Out:
#      A          B    C  D      E    F
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo

# %%
#get data from file in github
# !wget https://github.com/DeepanshuPasrija/Python02082021/blob/main/data.csv
# !ls ??

## DID NOT WORK
# Out:
# --2021-08-04 04:56:54--  https://github.com/DeepanshuPasrija/Python02082021/blob/main/data.csv
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘data.csv’
#
# data.csv                [ <=>                ] 737.43K  --.-KB/s    in 0.04s
#
# 2021-08-04 04:56:55 (16.9 MB/s) - ‘data.csv’ saved [755125]

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("/content/data.csv")
data.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
filter=["id","diagnosis","radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean","radius_se","texture_se"]
filteredData = data[filter]
filteredData.head()
# Out:
#          id diagnosis  ...  radius_se  texture_se
# 0    842302         M  ...     1.0950      0.9053
# 1    842517         M  ...     0.5435      0.7339
# 2  84300903         M  ...     0.7456      0.7869
# 3  84348301         M  ...     0.4956      1.1560
# 4  84358402         M  ...     0.7572      0.7813
#
# [5 rows x 14 columns]

# %%
filteredData.sort_index(axis=1, ascending=True).head(10)

##waht is axis??
# Out:
#    area_mean  compactness_mean  ...  texture_mean  texture_se
# 0     1001.0           0.27760  ...         10.38      0.9053
# 1     1326.0           0.07864  ...         17.77      0.7339
# 2     1203.0           0.15990  ...         21.25      0.7869
# 3      386.1           0.28390  ...         20.38      1.1560
# 4     1297.0           0.13280  ...         14.34      0.7813
# 5      477.1           0.17000  ...         15.70      0.8902
# 6     1040.0           0.10900  ...         19.98      0.7732
# 7      577.9           0.16450  ...         20.83      1.3770
# 8      519.8           0.19320  ...         21.82      1.0020
# 9      475.9           0.23960  ...         24.04      1.5990
#
# [10 rows x 14 columns]

# %%
filteredData.sort_values(by="diagnosis", ascending=True)
# Out:
#           id diagnosis  ...  radius_se  texture_se
# 284  8912284         B  ...     0.2913      1.3890
# 371  9012568         B  ...     0.1783      0.4125
# 367  9011495         B  ...     0.2527      0.7786
# 364  9010877         B  ...     0.1584      0.6124
# 363  9010872         B  ...     0.3389      1.4390
# ..       ...       ...  ...        ...         ...
# 146   869691         M  ...     0.3197      1.4260
# 379  9013838         M  ...     0.2114      1.0270
# 141   869104         M  ...     0.7049      1.3320
# 138   868826         M  ...     1.2960      1.4520
# 0     842302         M  ...     1.0950      0.9053
#
# [569 rows x 14 columns]

# %%
filteredData['diagnosis'].head
# Out:
# <bound method NDFrame.head of 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object>

# %%
filteredData[4:7]
# Out:
#          id diagnosis  ...  radius_se  texture_se
# 4  84358402         M  ...     0.7572      0.7813
# 5    843786         M  ...     0.3345      0.8902
# 6    844359         M  ...     0.4467      0.7732
#
# [3 rows x 14 columns]

# %%
filteredData.loc[:,["id", "diagnosis"]]

##filteredData.loc[start record:end record,["id", "diagnosis"]]
#if not specified start and end records all will show
# Out:
#            id diagnosis
# 0      842302         M
# 1      842517         M
# 2    84300903         M
# 3    84348301         M
# 4    84358402         M
# ..        ...       ...
# 564    926424         M
# 565    926682         M
# 566    926954         M
# 567    927241         M
# 568     92751         B
#
# [569 rows x 2 columns]

# %%
filteredData.loc[:10,["id", "diagnosis"]]
# Out:
#           id diagnosis
# 0     842302         M
# 1     842517         M
# 2   84300903         M
# 3   84348301         M
# 4   84358402         M
# 5     843786         M
# 6     844359         M
# 7   84458202         M
# 8     844981         M
# 9   84501001         M
# 10    845636         M

# %%
filteredData.iloc[0:10, 0:3]
# Out:
#          id diagnosis  radius_mean
# 0    842302         M        17.99
# 1    842517         M        20.57
# 2  84300903         M        19.69
# 3  84348301         M        11.42
# 4  84358402         M        20.29
# 5    843786         M        12.45
# 6    844359         M        18.25
# 7  84458202         M        13.71
# 8    844981         M        13.00
# 9  84501001         M        12.46

# %%
filteredData.iloc[5:10, 3:6]
# Out:
#    texture_mean  perimeter_mean  area_mean
# 5         15.70           82.57      477.1
# 6         19.98          119.60     1040.0
# 7         20.83           90.20      577.9
# 8         21.82           87.50      519.8
# 9         24.04           83.97      475.9

# %%
filteredData.iloc[5:10,:]
# Out:
#          id diagnosis  ...  radius_se  texture_se
# 5    843786         M  ...     0.3345      0.8902
# 6    844359         M  ...     0.4467      0.7732
# 7  84458202         M  ...     0.5835      1.3770
# 8    844981         M  ...     0.3063      1.0020
# 9  84501001         M  ...     0.2976      1.5990
#
# [5 rows x 14 columns]

# %%
filteredData.iloc[[5,6,7,10],0:3]
# Out:
#           id diagnosis  radius_mean
# 5     843786         M        12.45
# 6     844359         M        18.25
# 7   84458202         M        13.71
# 10    845636         M        16.02

# %%
topRows = filteredData.head(20).copy()
topRows
# Out:
#           id diagnosis  ...  radius_se  texture_se
# 0     842302         M  ...     1.0950      0.9053
# 1     842517         M  ...     0.5435      0.7339
# 2   84300903         M  ...     0.7456      0.7869
# 3   84348301         M  ...     0.4956      1.1560
# 4   84358402         M  ...     0.7572      0.7813
# 5     843786         M  ...     0.3345      0.8902
# 6     844359         M  ...     0.4467      0.7732
# 7   84458202         M  ...     0.5835      1.3770
# 8     844981         M  ...     0.3063      1.0020
# 9   84501001         M  ...     0.2976      1.5990
# 10    845636         M  ...     0.3795      1.1870
# 11  84610002         M  ...     0.5058      0.9849
# 12    846226         M  ...     0.9555      3.5680
# 13    846381         M  ...     0.4033      1.0780
# 14  84667401         M  ...     0.2121      1.1690
# 15  84799002         M  ...     0.3700      1.0330
# 16    848406         M  ...     0.4727      1.2400
# ...

# %%
#check for NA in records - important to clean data
pd.isna(filteredData).head(10)
# Out:
#       id  diagnosis  radius_mean  ...  fractal_dimension_mean  radius_se  texture_se
# 0  False      False        False  ...                   False      False       False
# 1  False      False        False  ...                   False      False       False
# 2  False      False        False  ...                   False      False       False
# 3  False      False        False  ...                   False      False       False
# 4  False      False        False  ...                   False      False       False
# 5  False      False        False  ...                   False      False       False
# 6  False      False        False  ...                   False      False       False
# 7  False      False        False  ...                   False      False       False
# 8  False      False        False  ...                   False      False       False
# 9  False      False        False  ...                   False      False       False
#
# [10 rows x 14 columns]

# %%
filteredData.dropna(how="any")
# Out:
#            id diagnosis  ...  radius_se  texture_se
# 0      842302         M  ...     1.0950      0.9053
# 1      842517         M  ...     0.5435      0.7339
# 2    84300903         M  ...     0.7456      0.7869
# 3    84348301         M  ...     0.4956      1.1560
# 4    84358402         M  ...     0.7572      0.7813
# ..        ...       ...  ...        ...         ...
# 564    926424         M  ...     1.1760      1.2560
# 565    926682         M  ...     0.7655      2.4630
# 566    926954         M  ...     0.4564      1.0750
# 567    927241         M  ...     0.7260      1.5950
# 568     92751         B  ...     0.3857      1.4280
#
# [569 rows x 14 columns]

# %%
filteredData.fillna(value=1)
# Out:
#            id diagnosis  ...  radius_se  texture_se
# 0      842302         M  ...     1.0950      0.9053
# 1      842517         M  ...     0.5435      0.7339
# 2    84300903         M  ...     0.7456      0.7869
# 3    84348301         M  ...     0.4956      1.1560
# 4    84358402         M  ...     0.7572      0.7813
# ..        ...       ...  ...        ...         ...
# 564    926424         M  ...     1.1760      1.2560
# 565    926682         M  ...     0.7655      2.4630
# 566    926954         M  ...     0.4564      1.0750
# 567    927241         M  ...     0.7260      1.5950
# 568     92751         B  ...     0.3857      1.4280
#
# [569 rows x 14 columns]

# %%
inp = pd.Series([1,57,36,7,np.nan,9])

#inp.isna() works!
pd.isna(inp)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
filledinp= inp.fillna(value=23)
filledinp
#not working because this is a series. not a dataframe
# Out:
# 0     1.0
# 1    57.0
# 2    36.0
# 3     7.0
# 4    23.0
# 5     9.0
# dtype: float64

# %%
dropinp= inp.dropna(how="any")
dropinp
# Out:
# 0     1.0
# 1    57.0
# 2    36.0
# 3     7.0
# 5     9.0
# dtype: float64

# %%
import pandas as pd
import numpy as np

df2 = pd.DataFrame(
     {
         "A": np.array([1,2,np.nan,4], dtype="float32"), #special note - how to input using np.array, nan could not be input to int32 dtype
         "B": pd.Timestamp("20130102"),
         "C": pd.Series(1, index=list(range(4)), dtype="float32"),
         "D": np.array([3] * 4, dtype="int32"),
         "E": pd.Categorical(["test", "train", "test", "train"]),
         "F": "foo",
     }
 )

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  2.0 2013-01-02  1.0  3  train  foo
# 2  NaN 2013-01-02  1.0  3   test  foo
# 3  4.0 2013-01-02  1.0  3  train  foo

# %%
#df2['A']= df2['A'].cat.add_categories['Unknown']
df2['A'].fillna(50, inplace=True) #special note - how to replace in df
df2
# Out:
#       A          B    C  D      E    F
# 0   1.0 2013-01-02  1.0  3   test  foo
# 1   2.0 2013-01-02  1.0  3  train  foo
# 2  50.0 2013-01-02  1.0  3   test  foo
# 3   4.0 2013-01-02  1.0  3  train  foo

# %%
filteredData.mean()
# Out:
# id                        3.037183e+07
# radius_mean               1.412729e+01
# texture_mean              1.928965e+01
# perimeter_mean            9.196903e+01
# area_mean                 6.548891e+02
# smoothness_mean           9.636028e-02
# compactness_mean          1.043410e-01
# concavity_mean            8.879932e-02
# concave points_mean       4.891915e-02
# symmetry_mean             1.811619e-01
# fractal_dimension_mean    6.279761e-02
# radius_se                 4.051721e-01
# texture_se                1.216853e+00
# dtype: float64

# %%
filteredData.value_counts()
# Out:
# id         diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se
# 911320502  B          13.170       18.22         84.28           537.3      0.07466          0.05994           0.04859         0.02870              0.1454         0.05549                 0.2023     0.6850        1
# 883270     B          14.220       27.85         92.55           623.9      0.08223          0.10390           0.11030         0.04408              0.1342         0.06129                 0.3354     2.3240        1
# 884626     B          12.890       14.11         84.95           512.2      0.08760          0.13460           0.13740         0.03980              0.1596         0.06409                 0.2025     0.4402        1
# ...

# %%
pdData = pd.Series(["CAT","UPPER","LOWER"])
pdData
# Out:
# 0      CAT
# 1    UPPER
# 2    LOWER
# dtype: object

# %%
pdData.str.lower()
# Out:
# 0      cat
# 1    upper
# 2    lower
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0 -2.679799 -0.634952  0.549299 -0.245671
# 1  0.392891  0.000559 -1.547435  0.107678
# 2  0.522545 -1.235572  0.666598 -0.710074
# 3 -1.127387  0.025390 -0.203412 -1.490468
# 4 -0.358091  0.235449 -0.692873  0.660648
# 5  0.180117  0.566436 -0.578606  1.011429
# 6 -0.923079  1.072102  0.461779  0.759092
# 7  0.627226  0.035513  1.390198 -1.821132
# 8 -0.051740 -0.117987 -0.069808 -0.023415
# 9  0.017928 -0.007108 -1.824320  0.156290

# %%
filteredData.diagnosis.str.lower()
# Out:
# 0      m
# 1      m
# 2      m
# 3      m
# 4      m
#       ..
# 564    m
# 565    m
# 566    m
# 567    m
# 568    b
# Name: diagnosis, Length: 569, dtype: object

# %%
filteredData
# Out:
#            id diagnosis  ...  radius_se  texture_se
# 0      842302         M  ...     1.0950      0.9053
# 1      842517         M  ...     0.5435      0.7339
# 2    84300903         M  ...     0.7456      0.7869
# 3    84348301         M  ...     0.4956      1.1560
# 4    84358402         M  ...     0.7572      0.7813
# ..        ...       ...  ...        ...         ...
# 564    926424         M  ...     1.1760      1.2560
# 565    926682         M  ...     0.7655      2.4630
# 566    926954         M  ...     0.4564      1.0750
# 567    927241         M  ...     0.7260      1.5950
# 568     92751         B  ...     0.3857      1.4280
#
# [569 rows x 14 columns]

# %%
pieces = [df[5:9], df[0:5]]

# %%
output = pd.concat(pieces)
output
# Out:
#           0         1         2         3
# 5  0.180117  0.566436 -0.578606  1.011429
# 6 -0.923079  1.072102  0.461779  0.759092
# 7  0.627226  0.035513  1.390198 -1.821132
# 8 -0.051740 -0.117987 -0.069808 -0.023415
# 0 -2.679799 -0.634952  0.549299 -0.245671
# 1  0.392891  0.000559 -1.547435  0.107678
# 2  0.522545 -1.235572  0.666598 -0.710074
# 3 -1.127387  0.025390 -0.203412 -1.490468
# 4 -0.358091  0.235449 -0.692873  0.660648

# %%
filteredData.groupby("diagnosis").sum()
# Out:
#                    id  radius_mean  ...  radius_se  texture_se
# diagnosis                           ...
# B          9476145391     4336.309  ...   101.4174    435.6757
# M          7805426694     3702.120  ...   129.1255    256.7139
#
# [2 rows x 13 columns]

# %%
filteredData.groupby(["id", "diagnosis"]).sum() #if [] not given in id, diagnosis it will give error
# Out:
#                      radius_mean  texture_mean  ...  radius_se  texture_se
# id        diagnosis                             ...
# 8670      M                15.46         19.48  ...     0.4743      0.7859
# 8913      B                12.89         13.12  ...     0.1532      0.4690
# 8915      B                14.96         19.10  ...     0.2877      0.9480
# 9047      B                12.94         16.17  ...     0.1458      0.9050
# 85715     M                13.17         18.66  ...     0.2871      0.8937
# ...                          ...           ...  ...        ...         ...
# 911157302 M                21.10         20.52  ...     0.6643      1.3610
# 911296201 M                17.08         27.15  ...     0.9291      1.1520
# 911296202 M                27.42         26.27  ...     2.5470      1.3060
# 911320501 B                11.60         18.36  ...     0.1816      0.7656
# 911320502 B                13.17         18.22  ...     0.2023      0.6850
#
# ...

# %%
filteredData.groupby("diagnosis").mean()
# Out:
#                      id  radius_mean  ...  radius_se  texture_se
# diagnosis                             ...
# B          2.654382e+07    12.146524  ...   0.284082    1.220380
# M          3.681805e+07    17.462830  ...   0.609083    1.210915
#
# [2 rows x 13 columns]

# %%
# pivot exercise

df = pd.DataFrame({
    "A":["one","one","two","three"]*3,
    "B":["A","B","C"]*4,
    "C":["hello","hello","hello","bye","bye","bye"]*2,
    "D":np.random.randn(12),
    "E":np.random.randn(12),

})
df
# Out:
#         A  B      C         D         E
# 0     one  A  hello  1.193101 -1.134722
# 1     one  B  hello -1.038551 -1.202837
# 2     two  C  hello  1.277335 -0.089316
# 3   three  A    bye -0.855837  0.439562
# 4     one  B    bye  0.199361  0.876135
# 5     one  C    bye -0.063320 -1.104327
# 6     two  A  hello -1.258814 -1.669427
# 7   three  B  hello  2.328889  0.536620
# 8     one  C  hello -0.087039 -1.685036
# 9     one  A    bye -1.485887 -0.816677
# 10    two  B    bye  0.573582  0.480875
# 11  three  C    bye  0.539880 -0.195634

# %%
pd.pivot_table(df, values="D",index=["A","B"],columns=["C"])
# Out:
# C             bye     hello
# A     B
# one   A -1.485887  1.193101
#       B  0.199361 -1.038551
#       C -0.063320 -0.087039
# three A -0.855837       NaN
#       B       NaN  2.328889
#       C  0.539880       NaN
# two   A       NaN -1.258814
#       B  0.573582       NaN
#       C       NaN  1.277335

# %%
filteredData.to_csv("NewData.csv")

# %%
newdata = pd.read_csv("/content/NewData.csv")
newdata
# Out:
#      Unnamed: 0        id  ... radius_se  texture_se
# 0             0    842302  ...    1.0950      0.9053
# 1             1    842517  ...    0.5435      0.7339
# 2             2  84300903  ...    0.7456      0.7869
# 3             3  84348301  ...    0.4956      1.1560
# 4             4  84358402  ...    0.7572      0.7813
# ..          ...       ...  ...       ...         ...
# 564         564    926424  ...    1.1760      1.2560
# 565         565    926682  ...    0.7655      2.4630
# 566         566    926954  ...    0.4564      1.0750
# 567         567    927241  ...    0.7260      1.5950
# 568         568     92751  ...    0.3857      1.4280
#
# [569 rows x 15 columns]

# %%
filteredData.to_excel("NewData.xlsx")

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
numbers = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2020', periods=1000))

# %%
numbers= numbers.cumsum()
numbers.plot()

# %%
df = pd.DataFrame(np.random.randn(1000,4), index=numbers.index, columns=['A','B','C','D'])

# %%
df.plot()

# %%
plt.legend(loc="best") #alone will not work
# Out:
# No handles with labels found to put in legend.

# %%
df = df.cumsum()
plt.figure()
df.plot()
plt.legend()
